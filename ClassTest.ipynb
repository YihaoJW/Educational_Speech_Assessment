# %%
from AsrLcss import AsrLcss
from glob import glob
from nltk.stem import LancasterStemmer

# %%
# Load the data
data = glob("Result/*.plist")

# %%
LCSS_CAL = AsrLcss(dict_path='yrs12_passages.csv',stemmer=LancasterStemmer())

# %%
it = iter(data)

# %%
while True:
    try:
        path = next(it)
        LCSS_CAL.read_student_text(path)
        break
    except KeyError:
        continue
    except StopIteration:
        break

# %%
LCSS_CAL.nice_print()
# Out:
# Student ID: 405
# Passage ID: 21072
# Session ID: 55428d8298d7a
# Reference Text:
# 	 monte loved cooking for people his favorite thing to make was tacos and refried beans when he made them he felt like a master chef
#
# Student Text:
# 	 Monitor loved and cooking for people his favorite thing was tacos and refried beans then he made them and he felt like a master chief shift
#
# Result:
# 	 loved<0.17> and<A> cooking<0.59> for<0.67> people<0.69> his<0.65> favorite<0.64> thing<0.69> to<R> make<R> was<0.83> tacos<0.86> and<0.86> refried<0.85> beans<0.89> then<A> when<R> he<0.86> made<0.85> them<0.87> and<A> he<0.86> felt<0.85> like<0.81> a<0.46> master<0.80> chief<A> shift<A> chef<R>

# %%
LCSS_CAL
