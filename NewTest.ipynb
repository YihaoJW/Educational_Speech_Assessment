# %%
import json
import pandas as pd

# %%
df1 = pd.read_csv('yrs12_passages.csv').set_index('passage_id')

# %%
dict1 = df1.to_dict()

# %%
dict1['passage']
# Out:
# {21002: 'Margaret Marie fell on the playground. "Ouch! I\'m bleeding!" she yelled. The yard duty lady took her to see the nurse. The nurse carefully washed her knee and bandaged it.',
#  21003: "Tim grew very tall. When he was ten, everyone thought he'd play basketball. But Tim surprised them all. He loved to play the piano.",
#  21007: 'Juan loved to play baseball with his friends. Most of all he liked it when he could be the catcher. He caught most of the balls easily in his glove.',
#  21009: 'Blackjack was a playful bouncy dog. He loved to catch his toys when Thomas threw them for him. He almost never missed when the ball was tossed.',
#  21010: 'Emily loved balloons. She stood in line to get the perfect red balloon. A heavy wind ripped it from her hand, and it went sailing into the air.',
#  21011: 'Suzy watched her balloon sail away into the sky. She was sad to see it go, but she quickly ran and caught it.',
# ...

# %%
with open('yrs12_passages.json', 'w') as f:
    json.dump(dict1['passage'], f)
